# %% [markdown]
# # Joshua Chavez
# ## Week 15  4/23/24
# ### Python  Data cleaning and vizulization project - Python Stock Market Project Amazon

# %%
#norm inputs
import numpy as np
from numpy.random import randn
import pandas as pd

#ploting modules 
import matplotlib as mpl
import matplotlib.pyplot as plt

#comand so that plots apper on the same page

# %matplotlib inline

# %%
#Upload dataset from a csv file
data = pd.read_csv("AMZN.csv")

# %%
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
data.count
# Out:
# <bound method DataFrame.count of             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
# ...

# %%
data.max
# Out:
# <bound method DataFrame.max of             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2242 non-null   object
#  1   Source     2242 non-null   object
#  2   Open       2241 non-null   float64
#  3   High       2240 non-null   float64
#  4   Low        2242 non-null   float64
#  5   Close      2239 non-null   float64
#  6   Adj Close  2241 non-null   float64
#  7   Volume     2242 non-null   int64
#  8   Stock      2242 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 157.8+ KB

# %%
data.tail(10)
# Out:
#             Date Source         Open         High          Low        Close  \
# 2232  11/13/2020  yahoo  3122.000000  3141.719971  3085.389893  3128.810059
# 2233  11/16/2020  yahoo  3093.199951  3142.699951  3072.689941  3131.060059
# 2234  11/17/2020  yahoo  3183.540039  3189.250000  3135.260010  3135.659912
# 2235  11/18/2020  yahoo  3134.000000  3140.000000  3105.100098  3105.459961
# 2236  11/19/2020  yahoo  3105.310059  3125.000000  3080.919922  3117.020020
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# 2232  3128.810059  3756200  amazon
# 2233  3131.060059  3808700  amazon
# ...

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2241.000000  2240.000000  2242.000000  2239.000000  2241.000000
# mean    991.401419  1002.190218   979.221717   991.895355   991.190696
# std     802.269032   811.968123   790.843600   801.664757   801.654109
# min     173.809998   178.250000   172.000000   175.929993   175.929993
# 25%     320.359985   323.687500   315.807487   321.385010   320.510010
# 50%     717.380005   723.394989   712.629975   719.299988   719.070007
# 75%    1660.000000  1679.964966  1633.707459  1661.830017  1660.510010
# max    3547.000000  3552.250000  3486.689941  3531.449951  3531.449951
#
#              Volume
# count  2.242000e+03
# mean   4.118187e+06
# std    2.278888e+06
# min    0.000000e+00
# 25%    2.688550e+06
# 50%    3.528700e+06
# 75%    4.839800e+06
# max    2.385610e+07

# %%
data.shape
# Out:
# (2242, 9)

# %%
data.values
# Out:
# array([['1/3/2012', 'yahoo', 175.889999, ..., 179.029999, 5110800,
#         'amazon'],
#        ['1/4/2012', 'yahoo', 179.21000700000002, ..., 177.509995,
#         4205200, 'amazon'],
#        ['1/5/2012', 'yahoo', 175.940002, ..., 177.610001, 3809100,
#         'amazon'],
#        ...,
#        ['11/24/2020', 'yahoo', 3100.5, ..., 3118.060059, 3602100,
#         'amazon'],
#        ['11/25/2020', 'yahoo', 3141.8701170000004, ..., 3185.070068,
#         3790400, 'amazon'],
#        ['11/27/2020', 'yahoo', 3211.26001, ..., 3195.340088, 2392900,
#         'amazon']], dtype=object)

# %%
data["Adj Close"]
# Out:
# 0        179.029999
# 1        177.509995
# 2        177.610001
# 3        182.610001
# 4        178.559998
#            ...
# 2237    3099.399902
# 2238    3098.389893
# 2239    3118.060059
# 2240    3185.070068
# 2241    3195.340088
# Name: Adj Close, Length: 2242, dtype: float64

# %%
data["Adj Close"].plot(legend=True, figsize = (18,4))

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2241.000000  2240.000000  2242.000000  2239.000000  2241.000000
# mean    991.401419  1002.190218   979.221717   991.895355   991.190696
# std     802.269032   811.968123   790.843600   801.664757   801.654109
# min     173.809998   178.250000   172.000000   175.929993   175.929993
# 25%     320.359985   323.687500   315.807487   321.385010   320.510010
# 50%     717.380005   723.394989   712.629975   719.299988   719.070007
# 75%    1660.000000  1679.964966  1633.707459  1661.830017  1660.510010
# max    3547.000000  3552.250000  3486.689941  3531.449951  3531.449951
#
#              Volume
# count  2.242000e+03
# mean   4.118187e+06
# std    2.278888e+06
# min    0.000000e+00
# 25%    2.688550e+06
# 50%    3.528700e+06
# 75%    4.839800e+06
# max    2.385610e+07

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2242 non-null   object
#  1   Source     2242 non-null   object
#  2   Open       2241 non-null   float64
#  3   High       2240 non-null   float64
#  4   Low        2242 non-null   float64
#  5   Close      2239 non-null   float64
#  6   Adj Close  2241 non-null   float64
#  7   Volume     2242 non-null   int64
#  8   Stock      2242 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 157.8+ KB

# %%
#count the num of numerical and non numerical colums
from pandas.api.types import is_numeric_dtype

# %%
from pandas.api.types import is_numeric_dtype

numeric_count = 0
non_numeric_count = 0

for c in data.columns:
    if is_numeric_dtype(data[c]):
        numeric_count += 1
    else:
        non_numeric_count += 1

print(f"Numerical columns: {numeric_count}")
print(f"Non-numeric columns: {non_numeric_count}")
# Out:
# Numerical columns: 6
# Non-numeric columns: 3

# %%
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         1
# High         2
# Low          0
# Close        3
# Adj Close    1
# Volume       0
# Stock        0
# dtype: int64

# %%
data.dropna()
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         1
# High         2
# Low          0
# Close        3
# Adj Close    1
# Volume       0
# Stock        0
# dtype: int64

# %%
#clean abnormal values 
data['Volume'].min()
# Out:
# 0

# %%
data['Volume'].sort_values(ascending=True).head(20)
# Out:
# 29            0
# 114           1
# 18            5
# 161           6
# 47           23
# 90           25
# 66           78
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# Name: Volume, dtype: int64

# %%
data = data[data['Volume']>100000]

# %%
data['Volume'].sort_values(ascending=True).head(20)
# Out:
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# 749     1513800
# 1167    1524100
# 151     1534300
# 417     1534700
# 152     1548100
# 1160    1563300
# 416     1566400
# Name: Volume, dtype: int64

# %%
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
#remove all columns that have a constant/single value 
constant_columns = []

for c in data.columns:
    n = len(data[c].unique())
    if n == 1:
        constant_columns.append(c)
        
print(f"Constant columns are: {constant_columns}")
# Out:
# Constant columns are: ['Source', 'Stock']

# %%
data.drop(columns= constant_columns,axis =1, inplace = True)
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume
# 0      179.029999  5110800
# 1      177.509995  4205200
# 2      177.610001  3809100
# ...

# %%
# adding year, month day y
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2235 entries, 0 to 2241
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2235 non-null   object
#  1   Open       2234 non-null   float64
#  2   High       2233 non-null   float64
#  3   Low        2235 non-null   float64
#  4   Close      2232 non-null   float64
#  5   Adj Close  2234 non-null   float64
#  6   Volume     2235 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 139.7+ KB

# %%
dateObject = pd.DatetimeIndex(data['Date'])
dateObject
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2020-11-13', '2020-11-16', '2020-11-17', '2020-11-18',
#                '2020-11-19', '2020-11-20', '2020-11-23', '2020-11-24',
#                '2020-11-25', '2020-11-27'],
#               dtype='datetime64[ns]', name='Date', length=2235, freq=None)

# %%
dateObject.day
# Out:
# Int64Index([ 3,  4,  5,  6,  9, 10, 11, 12, 13, 17,
#             ...
#             13, 16, 17, 18, 19, 20, 23, 24, 25, 27],
#            dtype='int64', name='Date', length=2235)

# %%
data['Day']=dateObject.day
data['Month']=dateObject.month
data['Year']=dateObject.year
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume  Day  Month  Year
# 0      179.029999  5110800    3      1  2012
# 1      177.509995  4205200    4      1  2012
# ...

# %%
data[['Date',"Day",'Month','Year']]
# Out:
#             Date  Day  Month  Year
# 0       1/3/2012    3      1  2012
# 1       1/4/2012    4      1  2012
# 2       1/5/2012    5      1  2012
# 3       1/6/2012    6      1  2012
# 4       1/9/2012    9      1  2012
# ...          ...  ...    ...   ...
# 2237  11/20/2020   20     11  2020
# 2238  11/23/2020   23     11  2020
# 2239  11/24/2020   24     11  2020
# 2240  11/25/2020   25     11  2020
# 2241  11/27/2020   27     11  2020
#
# [2235 rows x 4 columns]

# %%
#transform the values of volumen entirews to represent thousands
data['Volume'] = data['Volume']/1000
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 0      179.029999  5110.8    3      1  2012
# 1      177.509995  4205.2    4      1  2012
# ...

# %%
#data Visulization for analysis
data[['Year', 'Volume']].groupby('Year').sum().astype(int)
# Out:
#        Volume
# Year
# 2012  1018776
# 2013   747905
# 2014  1029066
# 2015   957102
# 2016  1038756
# 2017   882705
# 2018  1417897
# 2019   974729
# 2020  1166035

# %%
data[['Year', 'Volume']].groupby('Year').sum().astype(int).plot(figsize=(8, 6), y="Volume", fontsize=12, title="Stocks Volume over Years")

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 0      179.029999  5110.8    3      1  2012
# 1      177.509995  4205.2    4      1  2012
# ...

# %%
data[['Month', 'Volume']].groupby('Month').sum().astype(int).plot(figsize=(8, 6), y="Volume", fontsize=12, title="Stocks Volume over Months")

# %%
data[['Day', 'Volume']].groupby('Day').mean().plot.bar(figsize=(8, 6), y="Volume", fontsize=12, title="Stocks Volume over Days")

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 0      179.029999  5110.8    3      1  2012
# 1      177.509995  4205.2    4      1  2012
# ...

# %%
data['Date'] = pd.to_datetime(data["Date"], format="%m/%d/%Y")
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 0      179.029999  5110.8    3      1  2012
# 1      177.509995  4205.2    4      1  2012
# ...

# %%
data[['Date', 'Adj Close']].plot.bar(figsize=(10, 8), x = 'Date', y='Adj Close', fontsize=12, title="closeing price over dates")

# %%
data[['Date', 'Adj Close']].set_index('Date').plot(figsize=(10, 8), fontsize=12, title="Closing Price Over Dates")

# %%
#useing filters
#plot the adj close price tjat are smaller than open prices
#post 2015
data1 = data[data["Year"]>2015]

# %%
data1
# Out:
#            Date         Open         High          Low        Close  \
# 1006 2016-01-04   656.289978   657.719971   627.510010   636.989990
# 1007 2016-01-05   646.859985   646.909973   627.650024   633.789978
# 1008 2016-01-06   622.000000   639.789978   620.309998   632.650024
# 1009 2016-01-07   621.799988   630.000000   605.210022   607.940002
# 1010 2016-01-08   619.659973   624.140015   606.000000   607.049988
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 1006   636.989990  9314.5    4      1  2016
# 1007   633.789978  5822.6    5      1  2016
# ...

# %%
data1['Year'].min
# Out:
# <bound method Series.min of 1006    2016
# 1007    2016
# 1008    2016
# 1009    2016
# 1010    2016
#         ...
# 2237    2020
# 2238    2020
# 2239    2020
# 2240    2020
# 2241    2020
# Name: Year, Length: 1236, dtype: int64>

# %%
data1['Year'].max
# Out:
# <bound method Series.max of 1006    2016
# 1007    2016
# 1008    2016
# 1009    2016
# 1010    2016
#         ...
# 2237    2020
# 2238    2020
# 2239    2020
# 2240    2020
# 2241    2020
# Name: Year, Length: 1236, dtype: int64>

# %%
data2 = data[data['Adj Close'] < data['Open']]

# %%
data2
# Out:
#            Date         Open         High          Low        Close  \
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# 5    2012-01-10   181.100006   182.399994   177.100006   179.339996
# 6    2012-01-11   179.639999   180.770004   178.190002   178.899994
# 7    2012-01-12   179.419998   179.490005   175.750000   175.929993
# ...         ...          ...          ...          ...          ...
# 2234 2020-11-17  3183.540039  3189.250000  3135.260010  3135.659912
# 2235 2020-11-18  3134.000000  3140.000000  3105.100098  3105.459961
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 1      177.509995  4205.2    4      1  2012
# 4      178.559998  5056.9    9      1  2012
# ...

# %%
data3 = data2[data2["Year"]>2015]

# %%
data3
# Out:
#            Date         Open         High          Low        Close  \
# 1006 2016-01-04   656.289978   657.719971   627.510010   636.989990
# 1007 2016-01-05   646.859985   646.909973   627.650024   633.789978
# 1009 2016-01-07   621.799988   630.000000   605.210022   607.940002
# 1010 2016-01-08   619.659973   624.140015   606.000000   607.049988
# 1012 2016-01-12   625.250000   625.989990   612.239990   617.890015
# ...         ...          ...          ...          ...          ...
# 2234 2020-11-17  3183.540039  3189.250000  3135.260010  3135.659912
# 2235 2020-11-18  3134.000000  3140.000000  3105.100098  3105.459961
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 1006   636.989990  9314.5    4      1  2016
# 1007   633.789978  5822.6    5      1  2016
# ...

# %%
filter1 = data['Year']> 2015

# %%
filter1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2237     True
# 2238     True
# 2239     True
# 2240     True
# 2241     True
# Name: Year, Length: 2235, dtype: bool

# %%
filter2 = data['Adj Close'] <data['Open']
filter2
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2237     True
# 2238     True
# 2239    False
# 2240    False
# 2241     True
# Length: 2235, dtype: bool

# %%
data3[['Adj Close', 'Open']]
# Out:
#         Adj Close         Open
# 1006   636.989990   656.289978
# 1007   633.789978   646.859985
# 1009   607.940002   621.799988
# 1010   607.049988   619.659973
# 1012   617.890015   625.250000
# ...           ...          ...
# 2234  3135.659912  3183.540039
# 2235  3105.459961  3134.000000
# 2237  3099.399902  3117.020020
# 2238  3098.389893  3116.699951
# 2241  3195.340088  3211.260010
#
# [616 rows x 2 columns]

# %%
data3['Year'] = data3['Date'].dt.year  # Extracting the year from the Date column
result = data3[['Adj Close', 'Year']].groupby('Year').sum()
# Out:
# c:\Miniconda\envs\py37_default\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
result
# Out:
#           Adj Close
# Year
# 2016   88700.740235
# 2017  124082.879700
# 2018  204003.290281
# 2019  223714.578973
# 2020  295435.149416

# %%
result = data3[['Adj Close', 'Year']].groupby('Year').count()

# %%
result
# Out:
#       Adj Close
# Year
# 2016        127
# 2017        128
# 2018        124
# 2019        125
# 2020        112

# %%
result = data3[['Adj Close', 'Year']].groupby('Year').count().plot.bar(figsize=(10, 8), fontsize=12, title="Closing Price Over Years")

# %%
# compare the average hyigh low open and Adj Close values/prices over months 
result= data[['Month', 'High', 'Low', 'Open', 'Adj Close']].groupby('Month').mean()
result
# Out:
#               High          Low         Open    Adj Close
# Month
# 1       841.549944   823.186176   832.228852   833.664645
# 2       865.478075   841.024013   851.265175   851.284709
# 3       875.984353   853.220363   868.095725   869.441353
# 4       935.481024   909.793333   920.999785   921.559085
# 5       977.501573   960.332250   968.595708   969.712829
# 6      1030.305523  1010.421686  1020.797158  1020.935264
# 7      1117.510261  1090.640261  1105.218596  1105.226407
# 8      1124.288736  1103.972829  1114.122626  1114.643383
# 9      1137.103572  1110.570271  1126.507582  1123.582474
# 10     1134.387446  1105.711601  1122.155053  1119.413149
# 11     1114.245054  1089.462911  1102.558629  1102.657419
# 12      861.799519   842.490300   853.738857   851.398673

# %%
result.plot(figsize=(10,8), y = ['High', 'Low', 'Open', 'Adj Close'], 
            fontsize= 12, legend= True, title= " Compare the average of hig low open adj close"), plt.ylabel ("average of stock prices")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1f998ac5088>,
#  Text(0, 0.5, 'average of stock prices'))

# %%
result.plot(figsize=(10, 8), y=['High', 'Low', 'Open', 'Adj Close'], fontsize=12, legend=True, title="Progress")
plt.ylabel("Avg stock")
# Out:
# Text(0, 0.5, 'Avg stock')

# %%
r = data[["Month", 'Volume']].groupby('Month').sum().astype(int)
r
# Out:
#        Volume
# Month
# 1      889294
# 2      866714
# 3      849411
# 4      894848
# 5      697438
# 6      671267
# 7      792035
# 8      633655
# 9      650017
# 10     897270
# 11     743073
# 12     647949

# %%
r.min()
# Out:
# Volume    633655
# dtype: int32

# %%
r.max()
# Out:
# Volume    897270
# dtype: int32

# %%
r.idxmax()
# Out:
# Volume    10
# dtype: int64

# %%
r.idxmin()
# Out:
# Volume    8
# dtype: int64

# %%
r = data ['Volume']
s = r.idxmin()
l = r.idxmax()

print(s,l)
# Out:
# 2007 773

# %%
print(f"data with lowesat vol{data.iloc[s]["Date"]}")
# Out:
#   File "<ipython-input-75-174b3f7f42ec>", line 1
#     print(f"data with lowesat vol{data.iloc[s]["Date"]}")
#                                                    ^
# SyntaxError: invalid syntax

# %%
index_of_lowest_volume = data['Volume'].idxmin()
date_of_lowest_volume = data.loc[index_of_lowest_volume, 'Date']
print(f"Data with lowest volume: {date_of_lowest_volume}")
# Out:
# Data with lowest volume: 2019-12-24 00:00:00

# %%
#find the month and day the at has the lowest
#(adj Close) closeing avg price!
r = data[["Month", "Day", "Volume"]].groupby(["Month", "Day"]).mean()
r
# Out:
#                 Volume
# Month Day
# 1     2    3816.433333
#       3    3920.257143
#       4    5018.183333
#       5    4356.140000
#       6    4845.866667
# ...                ...
# 12    27   4340.116667
#       28   3922.800000
#       29   3647.675000
#       30   3182.640000
#       31   3445.683333
#
# [363 rows x 1 columns]

# %% [raw]
# r.idxmin()

# %%
r.idxmax()
# Out:
# Volume    (1, 31)
# dtype: object

# %%
print(f"The month and day with the lowest closeing{r.idxmin()[0]}, and  {r.idxmax()[0]} , month and day by the highest Vol" )
# Out:
# The month and day with the lowest closeing(7, 3), and  (1, 31) , month and day by the highest Vol
